# %% [markdown]
# <a href="https://colab.research.google.com/github/srabinarayan/LLM---Finetuning/blob/main/Inferencing_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets ctransformers langchain langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# ...

# %% [markdown]
# ### Import Libraries

# %%
from transformers import AutoTokenizer
import transformers
import torch
from langchain.llms import CTransformers

# %%
# # Hugging face repo name
# model = "meta-llama/Llama-2-7b-hf" # Text Generation Model

# tokenizer = AutoTokenizer.from_pretrained(model)

# %%
# Local CTransformers model - quantized version
llm = CTransformers(model='TheBloke/Llama-2-7B-Chat-GGML',
                    model_type='llama',
                    config={'max_new_tokens': 256,
                            'temperature': 0.01}
                    )
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# llama-2-7b-chat.ggmlv3.q2_K.bin:   0%|          | 0.00/2.87G [00:00<?, ?B/s]

# %%
prediction = llm.predict("Hi!, can you tell me the distance to the sun?")
print(prediction)
# Out:
# Answer:
# The distance from Earth to the Sun is about 93 million miles (149.6 million kilometers). This is called an astronomical unit, or AU. The distance between the Earth and the Sun varies slightly due to the elliptical shape of the Earth's orbit around the Sun. At its closest point, the distance is about 91.5 million miles (147 million kilometers), while at its farthest point, it is about 94.5 million miles (152.6 million kilometers).
#
# Note: The distance to the sun is not a fixed number and can vary slightly due to the elliptical shape of the Earth's orbit around the Sun.
